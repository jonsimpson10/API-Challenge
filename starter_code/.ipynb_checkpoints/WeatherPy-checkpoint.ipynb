# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Analysis:
#
# Temperature very strongly correlates with latitude for each hemisphere.  The r-squared value for the northern hemisphere is roughly -.9 and roughly .7 for the southern hemisphere.  In short, as you get closer to the equator, temperature increases.
#
# This correlation is not present for the other variables: humidity, wind speed, and cloudiness.  The r-squared values for these variables all fall below positive or negative .3, suggesting that these variables do not depend on latitude.
#
# Cloudiness data is highly subjective, as it is not subject to precise measurements like the other data.  In other words, cloudiness cannot be measured with precision, so the data points tend to cluster around convenient measurements, which is why the scatter plots for this variable appear to have concentrated lines.
#
# (Note: I wrote my analysis paragraphs before I changed the path for the api keys so that they would be outside of the repo.  I then reran the code to make sure that it would still work.  Doing so changed the r-values slightly, as new cities were used.  However, the overall trends still exist, though the southern hemisphere temperature/latitude correlation isn't as strong in this iteration.)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import sys

sys.path.insert(0, "/Users/jsimp/Desktop/Keys")

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
units="imperial"
base_url = f"{url}appid={weather_api_key}&units={units}&q="
lat = []
lng = []
temp = []
cloud = []
wind = []
country = []
date = []
humidity = []
name = []

print("Beginning Data Retrieval")
print("-----------------------------")

for city, x in zip(cities, range(1, len(cities)+1)):
    
    try:
        print(f"Processing Record {x} of {len(cities)} | {city}")
        response = requests.get(base_url+city).json()
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        temp.append(response["main"]["temp"])
        humidity.append(response["main"]["humidity"])
        cloud.append(response["clouds"]["all"])
        wind.append(response["wind"]["speed"])
        date.append(response["dt"])
        country.append(response["sys"]["country"])
        name.append(response["name"])
    except (KeyError, IndexError):
        print(f"{city} not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of 604 | beisfjord
# Processing Record 2 of 604 | oranjemund
# Processing Record 3 of 604 | palabuhanratu
# palabuhanratu not found. Skipping...
# Processing Record 4 of 604 | mandurah
# Processing Record 5 of 604 | vaini
# Processing Record 6 of 604 | cayenne
# Processing Record 7 of 604 | punta arenas
# Processing Record 8 of 604 | saint-denis
# Processing Record 9 of 604 | busselton
# Processing Record 10 of 604 | buraydah
# Processing Record 11 of 604 | hokitika
# Processing Record 12 of 604 | barentsburg
# barentsburg not found. Skipping...
# Processing Record 13 of 604 | bluff
# Processing Record 14 of 604 | kapaa
# Processing Record 15 of 604 | qaanaaq
# Processing Record 16 of 604 | antibes
# Processing Record 17 of 604 | nizhneyansk
# nizhneyansk not found. Skipping...
# Processing Record 18 of 604 | bengkulu
# Processing Record 19 of 604 | albany
# Processing Record 20 of 604 | barrow
# Processing Record 21 of 604 | qaqortoq
# Processing Record 22 of 604 | khatanga
# Processing Record 23 of 604 | rikitea
# Processing Record 24 of 604 | bredasdorp
# Processing Record 25 of 604 | mana
# Processing Record 26 of 604 | tasiilaq
# Processing Record 27 of 604 | lebu
# Processing Record 28 of 604 | saldanha
# Processing Record 29 of 604 | cabo san lucas
# Processing Record 30 of 604 | castro
# Processing Record 31 of 604 | egvekinot
# Processing Record 32 of 604 | bowen
# Processing Record 33 of 604 | gorontalo
# Processing Record 34 of 604 | thompson
# Processing Record 35 of 604 | ruteng
# Processing Record 178 of 604 | mar del plata
# Processing Record 179 of 604 | sorvag
# sorvag not found. Skipping...
# Processing Record 180 of 604 | kailua
# Processing Record 181 of 604 | arraial do cabo
# Processing Record 182 of 604 | norman wells
# Processing Record 183 of 604 | haines junction
# Processing Record 184 of 604 | la ronge
# Processing Record 185 of 604 | nanortalik
# Processing Record 186 of 604 | abu samrah
# Processing Record 187 of 604 | narasannapeta
# Processing Record 188 of 604 | xuddur
# Processing Record 189 of 604 | imeni poliny osipenko
# Processing Record 190 of 604 | ostrovnoy
# Processing Record 191 of 604 | rio gallegos
# Processing Record 192 of 604 | san cristobal
# Processing Record 193 of 604 | sug-aksy
# sug-aksy not found. Skipping...
# Processing Record 194 of 604 | nouadhibou
# Processing Record 195 of 604 | vryburg
# Processing Record 196 of 604 | saint-philippe
# Processing Record 197 of 604 | muros
# Processing Record 198 of 604 | pemba
# Processing Record 199 of 604 | north platte
# Processing Record 200 of 604 | hasaki
# Processing Record 201 of 604 | port macquarie
# Processing Record 202 of 604 | grand gaube
# Processing Record 203 of 604 | belushya guba
# belushya guba not found. Skipping...
# Processing Record 204 of 604 | chanika
# Processing Record 205 of 604 | colares
# Processing Record 206 of 604 | nyaunglebin
# Processing Record 207 of 604 | kutum
# Processing Record 208 of 604 | porbandar
# Processing Record 209 of 604 | baykit
# Processing Record 210 of 604 | tuktoyaktuk
# Processing Record 211 of 604 | kendallville
# Processing Record 212 of 604 | pangoa
# Processing Record 213 of 604 | pathein
# Processing Record 214 of 604 | bajil
# Processing Record 215 of 604 | vestmanna
# Processing Record 216 of 604 | gotsu
# Processing Record 217 of 604 | gat
# Processing Record 218 of 604 | erpeli
# Processing Record 219 of 604 | alofi
# Processing Record 220 of 604 | poum
# Processing Record 221 of 604 | ojinaga
# Processing Record 222 of 604 | saint-augustin
# Processing Record 223 of 604 | tagusao
# Processing Record 224 of 604 | puro
# Processing Record 225 of 604 | necochea
# Processing Record 226 of 604 | ribas do rio pardo
# Processing Record 227 of 604 | shahr-e babak
# Processing Record 228 of 604 | chuy
# Processing Record 229 of 604 | manggar
# Processing Record 230 of 604 | cockburn town
# Processing Record 231 of 604 | broken hill
# Processing Record 232 of 604 | deer lake
# Processing Record 233 of 604 | puri
# Processing Record 234 of 604 | claresholm
# Processing Record 235 of 604 | alice
# Processing Record 236 of 604 | gornopravdinsk
# Processing Record 237 of 604 | bata
# Processing Record 238 of 604 | neyshabur
# Processing Record 239 of 604 | esperance
# Processing Record 240 of 604 | leningradskiy
# Processing Record 241 of 604 | terney
# Processing Record 242 of 604 | bokspits
# bokspits not found. Skipping...
# Processing Record 243 of 604 | shache
# Processing Record 244 of 604 | vostok
# Processing Record 245 of 604 | havoysund
# Processing Record 246 of 604 | meulaboh
# Processing Record 247 of 604 | ancud
# Processing Record 248 of 604 | pishin
# Processing Record 249 of 604 | olafsvik
# Processing Record 250 of 604 | ginda
# Processing Record 251 of 604 | whitehorse
# Processing Record 252 of 604 | bambous virieux
# Processing Record 400 of 604 | honningsvag
# Processing Record 401 of 604 | livingston
# Processing Record 402 of 604 | fortuna
# Processing Record 403 of 604 | zhuhai
# Processing Record 404 of 604 | khonuu
# khonuu not found. Skipping...
# Processing Record 405 of 604 | cienfuegos
# Processing Record 406 of 604 | isangel
# Processing Record 407 of 604 | vila franca do campo
# Processing Record 408 of 604 | ngunguru
# Processing Record 409 of 604 | traverse city
# Processing Record 410 of 604 | seydi
# Processing Record 411 of 604 | praia da vitoria
# Processing Record 412 of 604 | clonakilty
# Processing Record 413 of 604 | san antonio del norte
# Processing Record 414 of 604 | sainte-marie
# Processing Record 415 of 604 | medea
# Processing Record 416 of 604 | rivera
# Processing Record 417 of 604 | mutoko
# Processing Record 418 of 604 | souillac
# Processing Record 419 of 604 | touros
# Processing Record 420 of 604 | ilinsko-podomskoye
# ilinsko-podomskoye not found. Skipping...
# Processing Record 421 of 604 | yingkou
# Processing Record 422 of 604 | jinchang
# Processing Record 423 of 604 | kirensk
# Processing Record 424 of 604 | pisco
# Processing Record 425 of 604 | kenai
# Processing Record 426 of 604 | flinders
# Processing Record 427 of 604 | njombe
# Processing Record 428 of 604 | bengbu
# Processing Record 429 of 604 | volnovakha
# Processing Record 430 of 604 | prachuap khiri khan
# Processing Record 431 of 604 | gloucester
# Processing Record 432 of 604 | chute-aux-outardes
# Processing Record 433 of 604 | mrirt
# mrirt not found. Skipping...
# Processing Record 434 of 604 | radishchevo
# Processing Record 435 of 604 | ulladulla
# Processing Record 436 of 604 | belluru
# Processing Record 437 of 604 | kathu
# Processing Record 438 of 604 | sinnamary
# Processing Record 439 of 604 | isiolo
# Processing Record 440 of 604 | rawannawi
# rawannawi not found. Skipping...
# Processing Record 441 of 604 | kyren
# Processing Record 442 of 604 | zhezkazgan
# Processing Record 443 of 604 | chernyshevskiy
# Processing Record 444 of 604 | wuda
# Processing Record 445 of 604 | ornskoldsvik
# Processing Record 446 of 604 | urucara
# Processing Record 447 of 604 | mumford
# Processing Record 448 of 604 | kawalu
# Processing Record 449 of 604 | avera
# Processing Record 450 of 604 | riverton
# Processing Record 451 of 604 | elat
# Processing Record 452 of 604 | shangrao
# Processing Record 453 of 604 | buqayq
# buqayq not found. Skipping...
# Processing Record 454 of 604 | dalvik
# Processing Record 455 of 604 | wagar
# Processing Record 456 of 604 | ochakiv
# Processing Record 457 of 604 | aleksandrovskiy zavod
# Processing Record 458 of 604 | alice springs
# Processing Record 459 of 604 | sorland
# Processing Record 460 of 604 | springfield
# Processing Record 461 of 604 | doctor pedro p. pena
# doctor pedro p. pena not found. Skipping...
# Processing Record 462 of 604 | preston
# Processing Record 463 of 604 | mangrol
# Processing Record 464 of 604 | krasnoarmeysk
# Processing Record 465 of 604 | kropotkin
# Processing Record 466 of 604 | qandala
# Processing Record 467 of 604 | at-bashi
# Processing Record 468 of 604 | velingara
# Processing Record 469 of 604 | xacmaz
# Processing Record 470 of 604 | hof
# Processing Record 471 of 604 | dzhebariki-khaya
# Processing Record 545 of 604 | kholodnyy
# Processing Record 546 of 604 | qazvin
# Processing Record 547 of 604 | barsovo
# Processing Record 548 of 604 | lodja
# Processing Record 549 of 604 | banjar
# Processing Record 550 of 604 | sembe
# Processing Record 551 of 604 | forbes
# Processing Record 552 of 604 | bend
# Processing Record 553 of 604 | axim
# Processing Record 554 of 604 | nesbyen
# Processing Record 555 of 604 | lasa
# Processing Record 556 of 604 | bayburt
# Processing Record 557 of 604 | north battleford
# Processing Record 558 of 604 | nisia floresta
# Processing Record 559 of 604 | bubaque
# Processing Record 560 of 604 | dunedin
# Processing Record 561 of 604 | tonk
# Processing Record 562 of 604 | sao jose da coroa grande
# Processing Record 563 of 604 | clermont
# Processing Record 564 of 604 | port augusta
# Processing Record 565 of 604 | orange cove
# Processing Record 566 of 604 | nishihara
# Processing Record 567 of 604 | polson
# Processing Record 568 of 604 | channel-port aux basques
# Processing Record 569 of 604 | korla
# Processing Record 570 of 604 | gold coast
# Processing Record 571 of 604 | paamiut
# Processing Record 572 of 604 | miri
# Processing Record 573 of 604 | baie-comeau
# Processing Record 574 of 604 | spas-demensk
# Processing Record 575 of 604 | tilichiki
# Processing Record 576 of 604 | turka
# Processing Record 577 of 604 | mao
# Processing Record 578 of 604 | jalu
# Processing Record 579 of 604 | batagay-alyta
# Processing Record 580 of 604 | ust-kishert
# Processing Record 581 of 604 | ilave
# Processing Record 582 of 604 | tigil
# Processing Record 583 of 604 | sitka
# Processing Record 584 of 604 | kupino
# Processing Record 585 of 604 | maryborough
# Processing Record 586 of 604 | goundam
# Processing Record 587 of 604 | harper
# Processing Record 588 of 604 | aksu
# Processing Record 589 of 604 | khurai
# Processing Record 590 of 604 | olinda
# Processing Record 591 of 604 | te anau
# Processing Record 592 of 604 | high rock
# Processing Record 593 of 604 | hofn
# Processing Record 594 of 604 | ozgon
# ozgon not found. Skipping...
# Processing Record 595 of 604 | jalingo
# Processing Record 596 of 604 | kesova gora
# Processing Record 597 of 604 | pemangkat
# Processing Record 598 of 604 | kirakira
# Processing Record 599 of 604 | tsabong
# Processing Record 600 of 604 | buta
# Processing Record 601 of 604 | maues
# Processing Record 602 of 604 | tulun
# Processing Record 603 of 604 | sola
# Processing Record 604 of 604 | damavand

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = pd.DataFrame({
    "City":name,
    "Country":country,
    "Latitude":lat,
    "Longitude":lng,
    "Temperature (F)":temp,
    "Humidity (%)":humidity,
    "Wind Speed (mph)":wind,
    "Cloudiness (%)":cloud,
    "Date":date})

weather_data
# Out:
#            City Country  Latitude  Longitude  Temperature (F)  Humidity (%)  \
# 0     Beisfjord      NO     68.38      17.60            35.89            93
# 1    Oranjemund      NA    -28.55      16.43            59.83            83
# 2      Mandurah      AU    -32.55     115.70            64.90            88
# 3         Vaini      TO    -21.20    -175.20            77.00            83
# 4       Cayenne      GF      4.93     -52.33            86.00            70
# ..          ...     ...       ...        ...              ...           ...
# 552        Buta      CD      2.79      24.73            73.49            79
# 553       Maués      BR     -3.38     -57.72            85.80            78
# 554       Tulun      RU     54.56     100.58            30.16            83
# 555        Sola      VU    -13.88     167.55            82.44            76
# 556    Damāvand      IR     35.72      52.06            62.22            34
#
#      Wind Speed (mph)  Cloudiness (%)        Date
# 0               19.46             100  1587232186
# 1                3.09               1  1587232186
# 2                8.05             100  1587232186
# 3                9.17              75  1587232167
# 4                3.36              75  1587232022
# ..                ...             ...         ...
# 552              1.95              60  1587232193
# 553              3.09              44  1587232297
# 554              8.14              99  1587232297
# 555             10.36              73  1587232297
# 556              2.01             100  1587232298
#
# [557 rows x 9 columns]

# %%
weather_data.to_csv("../output_data/weather_data.csv", index=False, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_data["Humidity (%)"].max()
# Out:
# 100

# %%
#  Get the indices of cities that have humidity over 100%.
humid_cities = weather_data.loc[weather_data["Humidity (%)"] > 99, :]
humid_index = []
humid_index.append(humid_cities.index.unique())
humid_index
# Out:
# [Int64Index([48, 52, 89, 154, 292, 368, 376, 392, 397, 451, 488, 518], dtype='int64')]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
for index in humid_index:
    clean_city_data = weather_data.drop(index=index, inplace=False)
clean_city_data
# Out:
#            City Country  Latitude  Longitude  Temperature (F)  Humidity (%)  \
# 0     Beisfjord      NO     68.38      17.60            35.89            93
# 1    Oranjemund      NA    -28.55      16.43            59.83            83
# 2      Mandurah      AU    -32.55     115.70            64.90            88
# 3         Vaini      TO    -21.20    -175.20            77.00            83
# 4       Cayenne      GF      4.93     -52.33            86.00            70
# ..          ...     ...       ...        ...              ...           ...
# 552        Buta      CD      2.79      24.73            73.49            79
# 553       Maués      BR     -3.38     -57.72            85.80            78
# 554       Tulun      RU     54.56     100.58            30.16            83
# 555        Sola      VU    -13.88     167.55            82.44            76
# 556    Damāvand      IR     35.72      52.06            62.22            34
#
#      Wind Speed (mph)  Cloudiness (%)        Date
# 0               19.46             100  1587232186
# 1                3.09               1  1587232186
# 2                8.05             100  1587232186
# 3                9.17              75  1587232167
# 4                3.36              75  1587232022
# ..                ...             ...         ...
# 552              1.95              60  1587232193
# 553              3.09              44  1587232297
# 554              8.14              99  1587232297
# 555             10.36              73  1587232297
# 556              2.01             100  1587232298
#
# [545 rows x 9 columns]

# %%
# Export the City_Data into a csv
clean_city_data.to_csv("../output_data/clean_city_data.csv", index=False, header=True)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(clean_city_data["Latitude"], clean_city_data["Temperature (F)"], marker="o", facecolors="slategrey", edgecolors="black")
plt.title("City Latitude v. Temperature (F) (April 17, 2020)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig("../output_data/lat_temp_all.png")

# %% [markdown]
# This code is analyzing the relationship between temperature and latitude, plotting the values in the Latitude column and the Temperature column from the clean weather dataframe.  The graph shows that temperature increases as you approach the equator (latitude of 0).  This data appears to have a pretty strong correlation.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_city_data["Latitude"], clean_city_data["Humidity (%)"], marker="o", facecolors="slategrey", edgecolors="black")
plt.title("City Latitude v. Humidity (%) (April 17, 2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.savefig("../output_data/lat_hum_all.png")

# %% [markdown]
# This code analyzes the relationship between latitude and humidity, plotting the values in the Latitude column and the Humidity column from the clean weather dataframe.  There is little correlation between the two.  As the graph shows, high humidity occurs at all latitudes.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_city_data["Latitude"], clean_city_data["Cloudiness (%)"], marker="o", facecolors="slategrey", edgecolors="black")
plt.title("City Latitude v. Cloudiness (%) (April 17, 2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("../output_data/lat_cloud_all.png")

# %% [markdown]
# This code analyzes the relationship between latitude and cloudiness, plotting the values in the Latitude column and the Cloudiness column from the clean weather dataframe.  There is little correlation between the two.  Also, you can tell that the data points are somewhat arbitrary, in that they cluster along convienent points, e.g. 20%, 40%, multiples of fives.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_city_data["Latitude"], clean_city_data["Wind Speed (mph)"], marker="o", facecolors="slategrey", edgecolors="black")
plt.title("City Latitude v. Wind Speed (mph) (April 17, 2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("../output_data/lat_wind_all.png")

# %% [markdown]
# This code analyzes the relationship between latitude and wind speed, plotting the values in the Latitude column and the Wind Speed column from the clean weather dataframe.  There is little correlation between the two.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def line_reg(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    regress_values = x * slope + intercept
    plt.plot(x_values, regress_values, "r-")
    plt.legend([line_eq + "\nr-squared = " + str(round(rvalue, 2))])
    print(line_eq)
    print("The r-squared value is " + str(round(rvalue, 2)))

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_city = clean_city_data.loc[(clean_city_data["Latitude"]) >= 0, :]
southern_city = clean_city_data.loc[(clean_city_data["Latitude"]) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_city["Latitude"]
y_values = northern_city["Temperature (F)"]

line_reg(x_values,y_values)

plt.scatter(x_values, y_values, marker="o", facecolors="slategrey", edgecolors="black")
plt.title("Northern Hemisphere: \nCity Latitude v. Temperature (F) (April 17, 2020)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")

plt.savefig("../output_data/lat_temp_nor.png")
# Out:
# y = -1.06x + 95.54
# The r-squared value is -0.87

# %% [markdown]
# This code analyzes the relationship between latitude and temperature in the northern hemisphere, plotting the values in the Latitude column and the Temperature column from the northern hemisphere dataframe.  Like the data from the entire planet, this has a very strong correlation as well. The r-squared value is -.90, which is very high.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_city["Latitude"]
y_values = southern_city["Temperature (F)"]

line_reg(x_values,y_values)

plt.scatter(x_values, y_values, marker="o", facecolors="slategrey", edgecolors="black")
plt.title("Southern Hemisphere: \nCity Latitude v. Temperature (F) (April 17, 2020)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")

plt.savefig("../output_data/lat_temp_sou.png")
# Out:
# y = 0.56x + 82.9
# The r-squared value is 0.66

# %% [markdown]
# This code analyzes the relationship between latitude and temperature in the southern hemisphere, plotting the values in the Latitude column and the Temperature column from the southern hemisphere dataframe.  Like the data from the entire planet and northern hemisphere, this has a very strong correlation as well.  The correlation with an r-squared value of .71 is slightly less than the northern hemisphere data, which could be due, in part, to the smaller sample size of the data.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_city["Latitude"]
y_values = northern_city["Humidity (%)"]

line_reg(x_values,y_values)

plt.scatter(x_values, y_values, marker="o", facecolors="slategrey", edgecolors="black")
plt.title("Northern Hemisphere: \nCity Latitude v. Humidity (%) (April 17, 2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig("../output_data/lat_hum_nor.png")
# Out:
# y = 0.3x + 54.2
# The r-squared value is 0.28

# %% [markdown]
# This code analyzes the relationship between latitude and humidity in the northern hemisphere, plotting the values in the Latitude column and the Humidity column from the northern hemisphere dataframe.  These two factors have very little correlation with an r-squared value of .24.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_city["Latitude"]
y_values = southern_city["Humidity (%)"]

line_reg(x_values,y_values)

plt.scatter(x_values, y_values, marker="o", facecolors="slategrey", edgecolors="black")
plt.title("Southern Hemisphere: \nCity Latitude v. Humidity (%) (April 17, 2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig("../output_data/lat_hum_sou.png")
# Out:
# y = 0.11x + 72.47
# The r-squared value is 0.08

# %% [markdown]
# This code analyzes the relationship between latitude and humidity in the southern hemisphere, plotting the values in the Latitude column and the Humidity column from the southern hemisphere dataframe.  These two factors have very little correlation with an r-squared value of .16.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_city["Latitude"]
y_values = northern_city["Cloudiness (%)"]

line_reg(x_values,y_values)

plt.scatter(x_values, y_values, marker="o", facecolors="slategrey", edgecolors="black")
plt.title("Northern Hemisphere: \nCity Latitude v. Cloudiness (%) (April 17, 2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig("../output_data/lat_cloud_nor.png")
# Out:
# y = 0.15x + 50.44
# The r-squared value is 0.08

# %% [markdown]
# This code analyzes the relationship between latitude and cloudiness in the northern hemisphere, plotting the values in the Latitude column and the Cloudiness column from the northern hemisphere dataframe.  These two factors have very little correlation with an r-squared value of .22.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_city["Latitude"]
y_values = southern_city["Cloudiness (%)"]

line_reg(x_values,y_values)

plt.scatter(x_values, y_values, marker="o", facecolors="slategrey", edgecolors="black")
plt.title("Southern Hemisphere: \nCity Latitude v. Couldiness (%) (April 17, 2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig("../output_data/lat_cloud_sou.png")
# Out:
# y = 0.79x + 71.08
# The r-squared value is 0.3

# %% [markdown]
# This code analyzes the relationship between latitude and cloudiness in the southern hemisphere, plotting the values in the Latitude column and the Cloudiness column from the southern hemisphere dataframe.  These two factors have very little correlation with an r-squared value of .1.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_city["Latitude"]
y_values = northern_city["Wind Speed (mph)"]

line_reg(x_values,y_values)

plt.scatter(x_values, y_values, marker="o", facecolors="slategrey", edgecolors="black")
plt.title("Northern Hemisphere: \nCity Latitude v. Wind Speed (mph) (April 17, 2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig("../output_data/lat_wind_nor.png")
# Out:
# y = 0.02x + 7.8
# The r-squared value is 0.07

# %% [markdown]
# This code analyzes the relationship between latitude and wind speed in the northern hemisphere, plotting the values in the Latitude column and the Wind Speed column from the northern hemisphere dataframe.  These two factors have very little correlation with an r-squared value of .18.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_city["Latitude"]
y_values = southern_city["Wind Speed (mph)"]

line_reg(x_values,y_values)

plt.scatter(x_values, y_values, marker="o", facecolors="slategrey", edgecolors="black")
plt.title("Southern Hemisphere: \nCity Latitude v. Wind Speed (mph) (April 17, 2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig("../output_data/lat_wind_sou.png")
# Out:
# y = -0.1x + 5.21
# The r-squared value is -0.27

# %% [markdown]
# This code analyzes the relationship between latitude and wind speed in the southern hemisphere, plotting the values in the Latitude column and the Wind Speed column from the southern hemisphere dataframe.  These two factors have very little correlation with an r-squared value of -.3.
